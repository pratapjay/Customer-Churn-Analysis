# %% [markdown]
# # **🧠 Scenario:**

# %% [markdown]
# You're hired as a Data Analyst by a subscription-based ecommerce platform. Your task is to analyze customer behavior and predict which customers are likely to churn (i.e., not renew their subscription next month).

# %% [markdown]
# # **📊 PART 1 – Data Understanding & Exploration**

# %% [markdown]
# Show data types, missing values, and basic statistics.

# %% [markdown]
# Plot distributions of key columns (tenure, order value, etc.)

# %% [markdown]
# Find correlations between features and the target.

# %% [markdown]
# Identify outliers and handle them (if any).

# %% [markdown]
# # **🔧 PART 2 – Feature Engineering**

# %% [markdown]
# Create:
#
# order_frequency = total_orders / tenure_months
#
# is_active_recently = 1 if days_since_last_order < 30 else 0
#
# value_segment = High/Medium/Low based on avg order value using quantiles
#
# Encode binary categorical variables (e.g., referred_by_friend)

# %% [markdown]
# # **📈 PART 3 – Modeling: Predicting Churn**

# %% [markdown]
# Use logistic regression or decision tree to predict will_churn
#
# Split into train/test, train the model
#
# Evaluate using:
#
# Accuracy
#
# Confusion matrix
#
# Precision, Recall, F1
#
# ROC curve
